# %%
import pandas as pd
import numpy as np

nba = pd.read_csv("nba_all_elo.csv")
type(nba) # pandas è come una tabella di excel
pd.set_option("display.max.columns", None) # mostra tutte le colonne
pd.set_option("display.precision", 2) # aggiunge due decimali a tutti i valori

# %%
dir(nba)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %%
nba.shape # attributo: numero di righe e di colonne
# Out:
# (126314, 23)

# %%
len(nba) # numero di righe
# Out:
# 126314

# %%
nba.head() # metodo: intestazione e prime righe
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# ...

# %%
nba.head(20)
# Out:
#     gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0           1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1           1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2           2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3           2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4           3  194611020DTF   NBA        0     1947  11/2/1946           1
# 5           3  194611020DTF   NBA        1     1947  11/2/1946           1
# 6           4  194611020PRO   NBA        1     1947  11/2/1946           1
# 7           4  194611020PRO   NBA        0     1947  11/2/1946           1
# 8           5  194611020STB   NBA        1     1947  11/2/1946           1
# 9           5  194611020STB   NBA        0     1947  11/2/1946           1
# 10          6  194611030CLR   NBA        1     1947  11/3/1946           2
# ...

# %%
nba.tail(10) # metodo per vedere la fine del file (10 colonne)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126304      63153  201506070GSW   NBA        1     2015   6/7/2015
# 126305      63153  201506070GSW   NBA        0     2015   6/7/2015
# 126306      63154  201506090CLE   NBA        1     2015   6/9/2015
# 126307      63154  201506090CLE   NBA        0     2015   6/9/2015
# 126308      63155  201506110CLE   NBA        1     2015  6/11/2015
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 126304          98            1     CLE  Cavaliers   95  1708.17  1716.87
# 126305          99            1     GSW   Warriors   93  1806.20  1797.50
# ...

# %%
nba.tail(1) # metodo per vedere la fine del file (1 colonna)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id   fran_id  pts    elo_i    elo_n  \
# 126313         103            1     GSW  Warriors  105  1813.63  1822.29
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 126313      68.52    CLE  Cavaliers       97    1700.74    1692.09
#
#        game_location game_result  forecast notes
# 126313             A           W      0.52   NaN

# %%
nba.describe() # statistiche di base per ogni colonna: conta valori, media, deviazione standard
# Out:
#        gameorder   _iscopy    year_id  seasongame  is_playoffs        pts  \
# count  126314.00  126314.0  126314.00   126314.00    126314.00  126314.00
# mean    31579.00       0.5    1988.20       43.53         0.06     102.73
# std     18231.93       0.5      17.58       25.38         0.24      14.81
# min         1.00       0.0    1947.00        1.00         0.00       0.00
# 25%     15790.00       0.0    1975.00       22.00         0.00      93.00
# 50%     31579.00       0.5    1990.00       43.00         0.00     103.00
# 75%     47368.00       1.0    2003.00       65.00         0.00     112.00
# max     63157.00       1.0    2015.00      108.00         1.00     186.00
#
#            elo_i      elo_n  win_equiv    opp_pts  opp_elo_i  opp_elo_n  \
# count  126314.00  126314.00  126314.00  126314.00  126314.00  126314.00
# mean     1495.24    1495.24      41.71     102.73    1495.24    1495.24
# std       112.14     112.46      10.63      14.81     112.14     112.46
# ...

# %%
nba.info() # mostra le colonne
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
nba["team_id"].value_counts() # conta valori
# Out:
# team_id
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
#        ...
# PIT      60
# INJ      60
# TRH      60
# DTF      60
# SDS      11
# Name: count, Length: 104, dtype: int64

# %%
nba.loc[nba["fran_id"] == "Lakers", "team_id"].value_counts()
# location: ogni volta che fran=Lakers, mostra e conta il team
# Out:
# team_id
# LAL    5078
# MNL     946
# Name: count, dtype: int64

# %%
nba["date_played"] = pd.to_datetime(nba["date_game"])
# aggiungiamo una colonna convertendo al formato internazionale anno-mese-giorno

# %%
nba.shape
# Out:
# (126314, 24)

# %%
nba["date_played"]
# Out:
# 0        1946-11-01
# 1        1946-11-01
# 2        1946-11-02
# 3        1946-11-02
# 4        1946-11-02
#             ...
# 126309   2015-06-11
# 126310   2015-06-14
# 126311   2015-06-14
# 126312   2015-06-16
# 126313   2015-06-16
# Name: date_played, Length: 126314, dtype: datetime64[ns]

# %%
type(nba)
# Out:
# pandas.core.frame.DataFrame

# %%
nba["pt_aggiorn"] = nba["pts"]*10
# aggiungiamo una colonna in cui copiamo i valori moltiplicandoli per 10

# %%
nba.shape
# Out:
# (126314, 25)

# %%
nba.head(3)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts   elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.0  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.0  1309.65      42.01    NYK
#
#   opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  forecast  \
# 0   Knicks       68    1300.00    1306.72             H           L      0.64
# 1  Huskies       66    1300.00    1293.28             A           W      0.36
# 2   Knicks       47    1306.72    1297.07             H           W      0.63
#
#   notes date_played  pt_aggiorn
# ...

# %%
print(nba.loc[nba["team_id"] == "MNL", "date_played"].min())
print(nba.loc[nba["team_id"] == "MNL", "date_game"].min())
# Out:
# 1948-11-04 00:00:00
# 1/1/1949

# %%
print(nba.loc[nba["team_id"] == "MNL", "date_played"].max())
print(nba.loc[nba["team_id"] == "MNL", "date_game"].max())
# Out:
# 1960-03-26 00:00:00
# 4/9/1959

# %%
print(nba.loc[nba["team_id"] == "LAL", "date_played"].min())
# Out:
# 1960-10-19 00:00:00

# %%
# sfida: totale dei punti dei Boston Celtics
print(nba.loc[nba["team_id"] == "BOS", "pts"].sum())
# Out:
# 626484

# %%
print(nba.loc[nba["team_id"] == "BOS", "pts"].mean()) # media
# Out:
# 104.46623311655829

# %%
# creo una nuova serie
revenues_città = pd.Series([1200, 2330, 2355, 9900, 4954,
                      3492, 9845, 8942, 4895, 2489],
                    index=["Trieste", "Udine", "Monfalcone", "Gorizia", "Muggia",
                           "Codroipo", "Pordenone", "Cormons", "Aurisina", "Opicina"])
print(revenues)
type(revenues) # series e non data frame
# Out:
# Trieste       1200
# Udine         2330
# Monfalcone    2355
# Gorizia       9900
# Muggia        4954
# Codroipo      3492
# Pordenone     9845
# Cormons       8942
# Aurisina      4895
# Opicina       2489
# dtype: int64
# pandas.core.series.Series

# %%
revenues_città.values
# Out:
# array([1200, 2330, 2355, 9900, 4954, 3492, 9845, 8942, 4895, 2489])

# %%
type(revenues.values)
# Out:
# numpy.ndarray

# %%
type(nba["pts"])
# Out:
# pandas.core.series.Series

# %%
nba["pts"].values
# Out:
# array([ 66,  68,  63, ...,  91,  97, 105], shape=(126314,))

# %%
revenues_città.index
# Out:
# Index(['Trieste', 'Udine', 'Monfalcone', 'Gorizia', 'Muggia', 'Codroipo',
#        'Pordenone', 'Cormons', 'Aurisina', 'Opicina'],
#       dtype='object')

# %%
# sfida: scrivere codice per confermare una città nella tabella
"Trieste" in revenues_città.index
# Out:
# True

# %%
revenues_città[0]
# Out:
# /tmp/ipykernel_6006/3820575892.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   revenues_città[0]
# np.int64(1200)

# %%
employees_città = pd.Series({"Trieste": 800, "Opicina": 400, "Cividale": 250, "Udine": 500, "Pordenone": 430})
print(employees_città)
print(employees_città.values)
print(employees_città.index)
print(employees_città.keys()) # uguale a index
# Out:
# Trieste      800
# Opicina      400
# Cividale     250
# Udine        500
# Pordenone    430
# dtype: int64
# [800 400 250 500 430]
# Index(['Trieste', 'Opicina', 'Cividale', 'Udine', 'Pordenone'], dtype='object')
# Index(['Trieste', 'Opicina', 'Cividale', 'Udine', 'Pordenone'], dtype='object')

# %%
"Aurisina" in employees_città
# Out:
# False

# %%
city_dati = pd.DataFrame({
    "revenue": revenues_città,
    "employees": employees_città
}) # creiamo un data frame con due serie
print(city_dati) # NaN = not a number
print(city_dati.index)
print(city_dati.values)
# Out:
#             revenue  employees
# Aurisina     4895.0        NaN
# Cividale        NaN      250.0
# Codroipo     3492.0        NaN
# Cormons      8942.0        NaN
# Gorizia      9900.0        NaN
# Monfalcone   2355.0        NaN
# Muggia       4954.0        NaN
# Opicina      2489.0      400.0
# Pordenone    9845.0      430.0
# Trieste      1200.0      800.0
# Udine        2330.0      500.0
# Index(['Aurisina', 'Cividale', 'Codroipo', 'Cormons', 'Gorizia', 'Monfalcone',
#        'Muggia', 'Opicina', 'Pordenone', 'Trieste', 'Udine'],
#       dtype='object')
# [[4895.   nan]
#  [  nan  250.]
#  [3492.   nan]
#  [8942.   nan]
#  [9900.   nan]
#  [2355.   nan]
#  [4954.   nan]
#  [2489.  400.]
#  [9845.  430.]
#  [1200.  800.]
#  [2330.  500.]]

# %%
print(city_dati)
# Out:
#             revenue  employees
# Aurisina     4895.0        NaN
# Cividale        NaN      250.0
# Codroipo     3492.0        NaN
# Cormons      8942.0        NaN
# Gorizia      9900.0        NaN
# Monfalcone   2355.0        NaN
# Muggia       4954.0        NaN
# Opicina      2489.0      400.0
# Pordenone    9845.0      430.0
# Trieste      1200.0      800.0
# Udine        2330.0      500.0

# %%
city_dati
# Out:
#             revenue  employees
# Aurisina     4895.0        NaN
# Cividale        NaN      250.0
# Codroipo     3492.0        NaN
# Cormons      8942.0        NaN
# Gorizia      9900.0        NaN
# Monfalcone   2355.0        NaN
# Muggia       4954.0        NaN
# Opicina      2489.0      400.0
# Pordenone    9845.0      430.0
# Trieste      1200.0      800.0
# Udine        2330.0      500.0

# %%
city_dati["revenue"]
# Out:
# Aurisina      4895.0
# Cividale         NaN
# Codroipo      3492.0
# Cormons       8942.0
# Gorizia       9900.0
# Monfalcone    2355.0
# Muggia        4954.0
# Opicina       2489.0
# Pordenone     9845.0
# Trieste       1200.0
# Udine         2330.0
# Name: revenue, dtype: float64

# %%
city_dati.axes[0] # 0 = indici
# Out:
# Index(['Aurisina', 'Cividale', 'Codroipo', 'Cormons', 'Gorizia', 'Monfalcone',
#        'Muggia', 'Opicina', 'Pordenone', 'Trieste', 'Udine'],
#       dtype='object')

# %%
city_dati.axes[1] # 1 = colonne
# Out:
# Index(['revenue', 'employees'], dtype='object')

# %%
city_dati.axes[0][1] # nome del primo elemento delle righe
# Out:
# 'Cividale'

# %%
city_dati.axes[0][6] # riga 6 del primo indice
# Out:
# 'Muggia'

# %%
city_dati.axes[1][0] # nome del primo elemento delle colonne
# Out:
# 'revenue'

# %%
#.loc (label) e .iloc (indici numerici)
revenues_città[1]
# Out:
# /tmp/ipykernel_6006/2715378487.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   revenues_città[1]
# np.int64(2330)

# %%
revenues_città.iloc[1] # futura modalità corretta
# Out:
# np.int64(2330)

# %%
revenues_città["Udine"]
# Out:
# np.int64(2330)

# %%
revenues_città
# Out:
# Trieste       1200
# Udine         2330
# Monfalcone    2355
# Gorizia       9900
# Muggia        4954
# Codroipo      3492
# Pordenone     9845
# Cormons       8942
# Aurisina      4895
# Opicina       2489
# dtype: int64

# %%
revenues_città[:"Muggia"] # slice, ma non esclude l'ultimo elemento
# Out:
# Trieste       1200
# Udine         2330
# Monfalcone    2355
# Gorizia       9900
# Muggia        4954
# dtype: int64

# %%
revenues_città[:"Muggia":2]
# Out:
# Trieste       1200
# Monfalcone    2355
# Muggia        4954
# dtype: int64

# %%
colori = pd.Series(
    ["rosso", "blu", "verde", "viola", "giallo"],
    index=[1, 2, 3, 5, 8])

# %%
colori[4] # in questo caso non funziona l'indice numerico!!!
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Python/jupyter_sandbox/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 4
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[121], line 1
# ----> 1 colori[4] # in questo caso non funziona l'indice numerico
#
# ...

# %%
print(colori.iloc[4])
print(colori[8])
print(colori.loc[8])
# Out:
# giallo
# giallo
# giallo

# %%
print(colori.iloc[2:4]) # giallo (indice 4) è escluso
print(colori.loc[3:8]) # giallo è incluso!
print(colori.loc[3:10]) # giallo è incluso!
# Out:
# 3    verde
# 5    viola
# dtype: object
# 3     verde
# 5     viola
# 8    giallo
# dtype: object
# 3     verde
# 5     viola
# 8    giallo
# dtype: object

# %%
city_dati.loc["Trieste", "employees"] # è quello che avevamo fatto con l'nba
# Out:
# np.float64(800.0)

# %%
city_dati.loc["Gorizia":"Trieste", "employees"]
# Out:
# Gorizia         NaN
# Monfalcone      NaN
# Muggia          NaN
# Opicina       400.0
# Pordenone     430.0
# Trieste       800.0
# Name: employees, dtype: float64
